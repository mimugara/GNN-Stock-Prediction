    [0.5161290322580645, 0.5040322580645161, 0.5483870967741935, 0.5282258064516129, 0.5080645161290323],
    [0.5120967741935484, 0.5282258064516129, 0.4838709677419355, 0.5241935483870968, 0.5483870967741935],
    [0.5040322580645161, 0.5201612903225806, 0.5403225806451613, 0.5161290322580645, 0.5604838709677419],
    [0.5483870967741935, 0.4798387096774194, 0.5483870967741935, 0.5766129032258065, 0.5080645161290323]
]

MDD_data = [
    [-0.032410412736830096, -0.031390521946600525, -0.040698104603401175, -0.019216732868420294, -0.03456488244892164],
    [-0.03670299209503747, -0.023454069175013137, -0.03147551679572147, -0.03324969177625037, -0.033308964765287774],
    [-0.019125640561714508, -0.035018972967646333, -0.03818689143685139, -0.017877566066718975, -0.03209622966570369],
    [-0.019423400043698136, -0.03283804589380257, -0.021737638610525578, -0.030895149812591338, -0.02053520974627554],
    [-0.03224006964880588, -0.03537533842367413, -0.029745342774881944, -0.022300263007591692, -0.05236760188755962]
]

# Prepare data for boxplots
data = [IC_data, Rank_IC_data, ARR_data, AV_data, Sharpe_data, WR_data, MDD_data]
labels = ['IC', 'Rank IC', 'ARR', 'AV', 'Sharpe', 'WR', 'MDD']

# Colors for boxplots
colors = ['skyblue', 'lightgreen', 'lightgray', 'gold', 'lightpink', 'lightblue', 'darkturquoise']
fig, ax = plt.subplots(4, 2, figsize=(12, 20))
# Plotting each metric using boxplots
ax = ax.flatten()

for i, (metric_data, color) in enumerate(zip(data, colors)):
    row = i // 2
    col = i % 2
    
    ax[i].boxplot(metric_data, labels=categories, patch_artist=True, boxprops=dict(facecolor=color, color=color))
    ax[i].set_title(labels[i])
    ax[i].set_xticklabels(categories, rotation=45, ha='right')
    ax[i].grid(True)


plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_462024/4096118828.py:78: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax[i].boxplot(metric_data, labels=categories, patch_artist=True, boxprops=dict(facecolor=color, color=color))
# /tmp/ipykernel_462024/4096118828.py:78: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax[i].boxplot(metric_data, labels=categories, patch_artist=True, boxprops=dict(facecolor=color, color=color))
# /tmp/ipykernel_462024/4096118828.py:78: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax[i].boxplot(metric_data, labels=categories, patch_artist=True, boxprops=dict(facecolor=color, color=color))
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for each category and metric
IC_data = [
    [0.004609014891861099, 0.012429213922738193, 0.012179584545183603, 0.002039691292472238, 0.010679186524823286],
    [0.0168813829599892, 0.012659247881719373, -0.004987182917428509, 0.005315766309029224, 0.008982079255554404],
    [0.01270001275835052, 0.009706619361293621, 0.011234867020992408, 0.015419414273702926, 0.00721855689471879],
    [0.013980712106612472, 0.012409597653876937, 0.010153189386494253, 0.015818556268786935, 0.015906121372521467],
    [0.010577889275141963, 0.007794710718144458, 0.009617654266880108, 0.013450312594529631, 0.008614902316310933],
    [0.01602925601088935, 0.0026425363553253885, 0.0004942045766316064, 0.0097416044044397, 0.0002486297013529307],
    [0.012851301944505044, 0.01559419819865791, 0.005722459331186, 0.011146982337871168, 0.01458896699618604],
    [-0.03410797123806375, -0.030544888458519326, -0.010869329236367742, -0.022162669547529545, -0.0356316521172072]
]

# Prepare data for boxplots
data = [IC_data, Rank_IC_data, ARR_data, AV_data, Sharpe_data, WR_data, MDD_data]
labels = ['IC', 'Rank IC', 'ARR', 'AV', 'Sharpe', 'WR', 'MDD']
categories = ['corAnual', 'corDiària', 'corMensual', 
              'not+ind', 'not+subind', 
              'not+wiki', 'not+inv', 
              'ind+subind', 'ind+wiki', 
              'ind+inv', 'subind+wiki', 
              'subind+inv', 'wiki+inv']

# Colors for boxplots
colors = ['skyblue', 'lightgreen', 'lightgray', 'gold', 'lightpink', 'lightblue', 'darkturquoise']

# Plotting each metric using boxplots
fig, ax = plt.subplots(4, 2, figsize=(15, 20))
ax = ax.flatten()

for i, (metric_data, label) in enumerate(zip(data, labels)):
    row = i // 2
    col = i % 2
    
    # Selecting appropriate color for each category
    color_index = i % len(colors)
    color = colors[color_index]
    
    # Boxplot setup
    ax[i].boxplot(metric_data, patch_artist=True, boxprops=dict(facecolor=color, color=color))
    ax[i].set_title(label)
    ax[i].set_xticklabels(categories, rotation=45, ha='right')
    ax[i].grid(True)


plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Parsed results from the input provided
results = [
    ('corrAnual', [0.12280768644197042, 0.00834363411619283], [0.8132563859059585, 0.9869765667486465], [0.22390301419950767, 0.017712440634324027], [0.21875106115657578, 0.0165491878639289], [0.026144268309510475, 0.00010957703265395574]),
    ('corrMensual', [0.16927634823702545, 0.010787105338003174], [0.7524979505036484, 0.9812781921044028], [0.2938980025017036, 0.023784681698855246], [0.28352857512180624, 0.021179879535597412], [0.055809021620987435, 0.00024719397938771165]),
    ('notícies', [0.02229747827084946, 0.005320905152507785], [0.807927326445845, 0.9785225326535868], [0.0869253126843974, 0.011295960406875201], [0.04358306734154687, 0.010569596604343532], [0.004431782209559988, 0.0001302380219759137]),
    ('indústria', [0.10626404740360197, 0.0067734173078637], [0.8757376157661058, 0.9321576123570425], [0.19705764035795553, 0.019965981267985555], [0.19211335241889735, 0.013455693587889875], [0.014774636569508365, 0.000462658582316702]),
    ('subindústria', [0.03644925732304373, 0.003990522509041028], [0.9057495474874392, 0.9837927451887566], [0.1355684048332298, 0.007988960393289115], [0.07033486119172955, 0.007949323065457706], [0.0035653119698703744, 6.49345378690108e-05]),
    ('wikidata', [0.05547454716308609, 0.006671865522918291], [0.8817014472285127, 0.9534744036168538], [0.11597919449562992, 0.01687798584285694], [0.10511773554784637, 0.01325529351007058], [0.006947995551984156, 0.0003124974634946145]),
    ('inversors', [0.012747190784969189, 0.00023869196801527628], [0.9005182587803671, 0.983001355508478], [0.04675964399638057, 0.000478025480768542], [0.02517349028653238, 0.0004772700155112755], [0.00128448632722137, 4.058408616813175e-06])
]


# Unpack the results
names = [result[0] for result in results]
jac_sim = [result[1] for result in results]
ham_sim = [result[2] for result in results]
cos_sim = [result[3] for result in results]
dice_sim = [result[4] for result in results]

# Split the similarity results into upstream and downstream for plotting
jac_sim_upstream = [sim[0] for sim in jac_sim]
jac_sim_downstream = [sim[1] for sim in jac_sim]
ham_sim_upstream = [sim[0] for sim in ham_sim]
ham_sim_downstream = [sim[1] for sim in ham_sim]
cos_sim_upstream = [sim[0] for sim in cos_sim]
cos_sim_downstream = [sim[1] for sim in cos_sim]
dice_sim_upstream = [sim[0] for sim in dice_sim]
dice_sim_downstream = [sim[1] for sim in dice_sim]

x = range(len(names))
width = 0.35  # the width of the bars

plt.figure(figsize=(15, 20))

# Jaccard Similarity
plt.subplot(4, 1, 1)
plt.bar(x, jac_sim_upstream, width, label='Correlacions positives', color='darkorange')
plt.bar([p + width for p in x], jac_sim_downstream, width, label='Correlacions negatives', color='royalblue')
plt.xticks([p + width/2 for p in x], names, rotation=45, fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel('Similitud Jaccard', fontsize=16)
plt.title('Similitud Jaccard', fontsize=18)
plt.legend(fontsize=14)
plt.grid(True)

# Hamming Similarity
plt.subplot(4, 1, 2)
plt.bar(x, ham_sim_upstream, width, color='darkorange')
plt.bar([p + width for p in x], ham_sim_downstream, width,color='royalblue')
plt.xticks([p + width/2 for p in x], names, rotation=45, fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel('Similitud Hamming', fontsize=16)
plt.title('Similitud Hamming', fontsize=18)
plt.grid(True)

# Cosine Similarity
plt.subplot(4, 1, 3)
plt.bar(x, cos_sim_upstream, width, label='Correlacions positives', color='darkorange')
plt.bar([p + width for p in x], cos_sim_downstream, width, label='Correlacions negatives', color='royalblue')
plt.xticks([p + width/2 for p in x], names, rotation=45, fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel('Similitud Cosine', fontsize=16)
plt.title('Similitud Cosine', fontsize=18)
plt.legend(fontsize=14)
plt.grid(True)

# Dice Similarity
plt.subplot(4, 1, 4)
plt.bar(x, dice_sim_upstream, width, label='Correlacions positives', color='darkorange')
plt.bar([p + width for p in x], dice_sim_downstream, width, label='Correlacions negatives', color='royalblue')
plt.xticks([p + width/2 for p in x], names, rotation=45, fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel('Similitud Dice', fontsize=16)
plt.title('Similitud Dice', fontsize=18)
plt.legend(fontsize=14)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for each category and metric
categories = ['corr anual (+)', 'corr anual (-)', 'corr mensual (+)', 'corr mensual (-)',
 'notíciesMensuals', 'indústria', 'subindústria', 'wikidata', 'stockholders', 'ideal anual (+)', 'ideal anual (-)', 'ideal mensual (+)', 'ideal mensual (-)']

# Edges data for each category
Edges_data = [
    71460.0, 2100.0,
    84310.18181818182, 5113.818181818182,
    6356.545454545455, 
    29463.0, 
    3625.0, 
    18810.0, 
    3955.0, 
    46336.0, 4426.0,  # Graf ideal Anual
    92665.63636363637, 4356.0]  # Graf ideal Mensual

# Colors for the bar plot
colors = ['skyblue', 'lightgreen', 'mediumaquamarine', 'gold', 'lightpink', 'lightblue', 
          'darkturquoise', 'purple', 'orange', 'coral', 'cyan', 'lightsalmon', 'gray']

# Create the bar plot
plt.figure(figsize=(14, 8))
bars = plt.bar(categories, Edges_data, color=colors)

# Add titles and labels with increased font sizes
plt.title("Nombre d'arestes per cada graf", fontsize=20)
plt.xlabel('Mètode de construcció del graf', fontsize=16)
plt.ylabel("Nombre d'arestes", fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)

# Display the values on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), va='bottom', ha='center', fontsize=10)

# Show the plot
plt.tight_layout()
plt.show()
